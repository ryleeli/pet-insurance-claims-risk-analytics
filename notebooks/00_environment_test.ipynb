# %%
print("Hello Pet Insurance Analytics")
# Out:
# Hello Pet Insurance Analytics

# %%
import pandas as pd
import numpy as np

print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
# Out:
# Pandas: 1.0.1
# NumPy: 1.18.1

# %%
import kagglehub

print("KaggleHub installed")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-87369aa41ed6> in <module>
# ----> 1 import kagglehub
#       2
#       3 print("KaggleHub installed")
#
# ModuleNotFoundError: No module named 'kagglehub'

# %%
# !pip install kagglehub

# %%
import kagglehub

print("KaggleHub installed")
# Out:
# KaggleHub installed

# %%
import kagglehub

path = kagglehub.competition_download("allstate-claims-severity")

print("Path to competition files:", path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-077d4824fbe8> in <module>
#       1 import kagglehub
#       2
# ----> 3 path = kagglehub.competition_download("allstate-claims-severity")
#       4
#       5 print("Path to competition files:", path)
#
# AttributeError: module 'kagglehub' has no attribute 'competition_download'

# %%
import kagglehub
import os

path = kagglehub.competition_download_files("allstate-claims-severity")

print("Path:", path)
print(os.listdir(path))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-1fb3814bd737> in <module>
#       2 import os
#       3
# ----> 4 path = kagglehub.competition_download_files("allstate-claims-severity")
#       5
#       6 print("Path:", path)
#
# AttributeError: module 'kagglehub' has no attribute 'competition_download_files'

# %%
import kagglehub

print(dir(kagglehub))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', 'auth', 'cache', 'clients', 'colab_cache_resolver', 'config', 'dataset_download', 'dataset_upload', 'datasets', 'datasets_helpers', 'env', 'exceptions', 'gcs_upload', 'handle', 'http_resolver', 'integrity', 'kaggle_cache_resolver', 'kagglehub', 'logger', 'login', 'model_download', 'model_upload', 'models', 'models_helpers', 'registry', 'resolver', 'whoami']
